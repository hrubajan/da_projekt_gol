# %%
import requests
import json
import pandas
from pprint import pprint
import os

# %%
# parametrem trip_id ktere davam rovnou za lomitko
trip_id = ['333_677_200302',
 '333_1072_200302',
 '333_557_200302',
 '333_1064_200302',
 '333_1115_200302',
 '333_1012_200302',
 '333_1052_200302',
 '333_1094_200302',
 '333_715_200302',
 '333_751_200302',
 '333_651_200307',
 '333_1026_200307',
 '333_653_200307',
 '333_1010_200307',
 '333_1037_200307',
 '333_636_200307',
 '333_1047_200307',
 '333_655_200307',
 '333_1024_200307',
 '333_673_200307',
 '333_1012_200307']

# %%
rady = []
for tripid in trip_id:
    api_key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImphbmR1bGFocnViYUBnbWFpbC5jb20iLCJpZCI6MjY0LCJuYW1lIjpudWxsLCJzdXJuYW1lIjpudWxsLCJpYXQiOjE1ODc2NDg5ODksImV4cCI6MTE1ODc2NDg5ODksImlzcyI6ImdvbGVtaW8iLCJqdGkiOiJiMGQzNGQzMC03ODNlLTQ0MWQtOTQwMC04MGMwNmZmYTQ3NDkifQ.j0q7LKzycT3zmVLxxkPlWKIYCkl_PYfjgIraFtRQ1YA"
    headers = {
    'Content-Type': 'application/json; charset=utf-8',
    'x-access-token': api_key
    }

    response1 = requests.get(f'https://api.golemio.cz/v2/gtfs/trips/{tripid}?includeStops=true&includeStopTimes=true', headers = headers)
    #print(response1)
    
    if response1.status_code == 200:
        info_all = json.loads(response1.text)
        final = pandas.json_normalize(info_all['stop_times'])
        final.drop(inplace=True,columns=['arrival_time_seconds','departure_time_seconds','drop_off_type','pickup_type','stop_headsign',
                                                'stop.properties.stop_code','stop.properties.stop_desc','stop.properties.stop_timezone','stop.properties.stop_url',
                                                'stop.properties.wheelchair_boarding','stop.properties.zone_id','stop.type','stop.geometry.type','stop.properties.level_id','stop.properties.location_type',
                                                'stop.properties.parent_station','stop.properties.platform_code','timepoint'])
        #newCols = ['ARRIVAL_TIME','DEPARTURE_TIME', 'SHAPE_DIST_TRAVELED', 'STOP_ID','STOP_SEQUENCE', 'TRIP_ID', 'GEOMETRY_COORDINATES','STOP_ID', 'STOP_NAME']
        final.columns = map(str.upper, final.columns)
        
        
        rady.append(final)
vysledek = pandas.concat(rady)
vysledek.to_csv('jizdnirad.csv', encoding="utf-8", index=False)
    
#     else:
#         final = pandas.DataFrame(columns=['ARRIVAL_TIME','DEPARTURE_TIME', 'SHAPE_DIST_TRAVELED', 
#                                           'STOP_ID','STOP_SEQUENCE', 'TRIP_ID', 'GEOMETRY_COORDINATES',
#                                           'STOP_ID', 'STOP_NAME'], index=[0])
#         if not os.path.isfile('jizdnirad.csv'):
#             final.to_csv('jizdnirad.csv', mode = 'a', sep=',', encoding="utf-8", index=False)
#         else:
#             final.to_csv('jizdnirad.csv', mode = 'a', sep=',', encoding="utf-8", index=False, header=False)

# %%
jizdni_rad = pandas.read_csv('jizdnirad.csv', encoding='utf-8', low_memory=False)

# %%
jizdni_rad
# Out:
#     ARRIVAL_TIME DEPARTURE_TIME  SHAPE_DIST_TRAVELED  STOP_ID  STOP_SEQUENCE  \
# 0        9:18:00        9:18:00              0.00000  U1503Z2              1
# 1        9:19:00        9:19:00              0.15836  U1502Z2              2
# 2        9:21:00        9:21:00              0.77992  U1501Z2              3
# 3        9:25:00        9:25:00              3.53721   U545Z2              4
# 4        9:26:00        9:26:00              3.91690   U546Z2              5
# ..           ...            ...                  ...      ...            ...
# 462      8:15:00        8:15:00             16.22898   U749Z2             24
# 463      8:16:00        8:16:00             16.56781   U656Z2             25
# 464      8:17:00        8:17:00             17.03180   U893Z4             26
# 465      8:19:00        8:19:00             17.58466   U488Z7             27
# 466      8:23:00        8:23:00             18.94779   U228Z5             28
#
#              TRIP_ID STOP.GEOMETRY.COORDINATES STOP.PROPERTIES.STOP_ID  \
# 0     333_677_200302      [14.45708, 49.96319]                 U1503Z2
# 1     333_677_200302      [14.45889, 49.96373]                 U1502Z2
# 2     333_677_200302      [14.46199, 49.96894]                 U1501Z2
# 3     333_677_200302      [14.46853, 49.99163]                  U545Z2
# 4     333_677_200302      [14.46768, 49.99496]                  U546Z2
# ..               ...                       ...                     ...
# 462  333_1012_200307      [14.45197, 50.02019]                  U749Z2
# 463  333_1012_200307      [14.45149, 50.02318]                  U656Z2
# 464  333_1012_200307      [14.45143, 50.02735]                  U893Z4
# 465  333_1012_200307      [14.45515, 50.03038]                  U488Z7
# 466  333_1012_200307      [14.46033, 50.04203]                  U228Z5
#
#      STOP.PROPERTIES.STOP_NAME
# 0    Dolní Břežany,Obecní úřad
# 1        Dolní Břežany,Náměstí
# 2     Dolní Břežany,Na kopečku
# 3                      Písnice
# 4                   Ke Březině
# ..                         ...
# 462                      Tempo
# 463               Sídliště Krč
# 464                     Zálesí
# 465              Nemocnice Krč
# 466                    Kačerov
#
# [467 rows x 9 columns]
