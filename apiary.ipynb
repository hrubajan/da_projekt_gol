# %% [markdown]
# # **Získávání data skrze APIs do souboru/tabulky**

# %%
import requests
import json
from pprint import pprint
import pandas as pd

# %%
api_key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImphbmR1bGFocnViYUBnbWFpbC5jb20iLCJpZCI6MjY0LCJuYW1lIjpudWxsLCJzdXJuYW1lIjpudWxsLCJpYXQiOjE1ODc2NDg5ODksImV4cCI6MTE1ODc2NDg5ODksImlzcyI6ImdvbGVtaW8iLCJqdGkiOiJiMGQzNGQzMC03ODNlLTQ0MWQtOTQwMC04MGMwNmZmYTQ3NDkifQ.j0q7LKzycT3zmVLxxkPlWKIYCkl_PYfjgIraFtRQ1YA"

headers = {
  'Content-Type': 'application/json; charset=utf-8',
  'x-access-token': api_key
}

# %% [markdown]
# Parametrem trip_id

# %%
trip_id = '333_1116_200302'

# FOR VEHICLE POSITIONS
#response1 = requests.get(f'https://api.golemio.cz/v2/vehiclepositions/{trip_id}?includePositions=true', headers = headers)

# FOR BUS STOPS
response1 = requests.get(f'https://api.golemio.cz/v2/gtfs/trips/{trip_id}?includeStops=true&includeStopTimes=true', headers = headers)

# %%
trip_id_info_all = json.loads(response1.text)

# %%
# FOR ALL POSITIONS
# dict = trip_id_info_all['properties']['all_positions']

# %%
# FOR BUS STOPS
dict = trip_id_info_all['stop_times']
#print(dict)

# %% [markdown]
# Zápis do souboru

# %%
# json_file = open("bus_stops.json", "w", encoding="utf-8")
# json_file.write(json.dumps(pokus))
# json_file.close()

# %% [markdown]
# Tvorba tabulky

# %%
bus_stops = pd.json_normalize(dict)

# %%
stops_clean = bus_stops.drop(columns=['arrival_time_seconds','departure_time_seconds','drop_off_type','pickup_type','stop_headsign',
                                                'stop.properties.stop_code','stop.properties.stop_desc','stop.properties.stop_timezone','stop.properties.stop_url',
                                                'stop.properties.wheelchair_boarding','stop.properties.zone_id','stop.type','stop.geometry.type','stop.properties.level_id','stop.properties.location_type',
                                                'stop.properties.parent_station','stop.properties.platform_code','timepoint'])

# %%
stops_clean.head(15)
# Out:
#    arrival_time departure_time  shape_dist_traveled  stop_id  stop_sequence  \
# 0      15:06:00       15:06:00              0.00000   U228Z1              1
# 1      15:09:00       15:09:00              1.39882   U488Z1              2
# 2      15:11:00       15:11:00              1.92168   U893Z3              3
# 3      15:12:00       15:12:00              2.41375   U656Z1              4
# 4      15:13:00       15:13:00              2.73871   U749Z1              5
# 5      15:15:00       15:15:00              3.49846   U194Z1              6
# 6      15:17:00       15:17:00              3.97468   U804Z1              7
# 7      15:18:00       15:18:00              4.30110   U335Z1              8
# 8      15:19:00       15:19:00              4.69875   U783Z1              9
# 9      15:20:00       15:20:00              5.15193   U369Z1             10
# 10     15:21:00       15:21:00              5.59591   U871Z1             11
# ...

# %%
# stops_clean.to_csv('stops_clean.csv', encoding='utf-8')
